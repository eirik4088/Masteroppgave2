# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of data points per cluster
num_points = 100

# Generate centroids
centroid = [[4, -1], [-4, 1], [-2, -5], [2, 5]]
norms = np.linalg.norm(centroid, axis=1, keepdims=True)
centroids = centroid/norms


# Generate data points around each centroid with noise
data = []

# Add noise level to the angle (adjust as needed)
angle_noise = np.pi / 18  # Adjust this value to control the amount of noise (e.g., π/18 radians is approximately 10 degrees)

for centroid in centroids:
    for _ in range(num_points):
        # Generate random noise for the angle
        noise_angle = np.random.uniform(-angle_noise, angle_noise)

        # Apply noise to the angle of the centroid coordinates
        new_angle = np.arctan2(centroid[1], centroid[0]) + noise_angle
        noise_point = np.array([np.cos(new_angle), np.sin(new_angle)])

        data.append(noise_point)

# Convert the data to a NumPy array
data = np.array(data)

# Visualize or use the generated data as needed

# %%
# Split data into clusters
cluster_1 = data[:num_points]
cluster_2 = data[num_points:2 * num_points]
cluster_3 = data[2 * num_points:3 * num_points]
cluster_4 = data[3 * num_points:4 * num_points]


# Create a scatter plot for each cluster with different colors
plt.scatter(cluster_1[:, 0], cluster_1[:, 1], label="Cluster 1", c="r", marker="o")
plt.scatter(cluster_2[:, 0], cluster_2[:, 1], label="Cluster 2", c="g", marker="s")
plt.scatter(cluster_3[:, 0], cluster_3[:, 1], label="Cluster 3", c="b", marker="^")
plt.scatter(cluster_4[:, 0], cluster_4[:, 1], label="Cluster 4", c="c", marker="x")


# Add labels and legend
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Clustered Data")
plt.legend()

# Display the plot
plt.show()

# %%
import numpy as np

# Number of points to generate
num_points = 31

# Generate evenly spaced angles to cover the unit circle
angles = np.linspace(0, 2 * np.pi, num_points, endpoint=False)

# Convert angles to 2D vectors
data_all = np.array([(np.cos(theta), np.sin(theta)) for theta in angles])

plt.scatter(data_all[:10, 0], data_all[:10, 1], label="Cluster 1", c="r", marker="o")
plt.scatter(data_all[10:20, 0], data_all[10:20, 1], label="Cluster 1", c="g", marker="o")
plt.scatter(data_all[20:30, 0], data_all[20:30, 1], label="Cluster 1", c="b", marker="o")
plt.scatter(data_all[30:40, 0], data_all[30:40, 1], label="Cluster 1", c="c", marker="o")
plt.scatter(data_all[40:50, 0], data_all[40:50, 1], label="Cluster 1", c="y", marker="o")
plt.scatter(data_all[50:60, 0], data_all[50:60, 1], label="Cluster 1", c="m", marker="o")
plt.scatter(data_all[60:70, 0], data_all[60:70, 1], label="Cluster 1", c="k", marker="o")

# Add labels and legend
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.title("Clustered Data")
plt.legend()

# Display the plot
plt.show()

# %%
dobbel = np.hstack((np.abs(data), ((data[:, 0]*data[:, 1])*2).reshape((len(data), 1))))

# %%
cluster_1 = dobbel[:num_points]
cluster_2 = dobbel[num_points:2 * num_points]
cluster_3 = dobbel[2 * num_points:3 * num_points]
cluster_4 = dobbel[3 * num_points:4 * num_points]

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Define marker styles and colors for each cluster
markers = ['o', 's', '^', 'x', 'D', 'P']
colors = ['r', 'g', 'b', 'c', 'm', 'y']

ax.scatter(cluster_1[:, 0], cluster_1[:, 1], cluster_1[:, 2], c='r', marker='o')
ax.scatter(cluster_2[:, 0], cluster_2[:, 1], cluster_2[:, 2], c='g', marker='s')
ax.scatter(cluster_3[:, 0], cluster_3[:, 1], cluster_3[:, 2], c='b', marker='^')
ax.scatter(cluster_4[:, 0], cluster_4[:, 1], cluster_4[:, 2], c='c', marker='x')


ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.title("Clustered 3D Data")
ax.legend()

# Display the 3D plot
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
dobbel_all = np.hstack((np.abs(data_all), ((data_all[:, 0]*data_all[:, 1])*2).reshape((len(data_all), 1))))
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

ax.scatter(dobbel_all[:10, 0], dobbel_all[:10, 1], dobbel_all[:10, 2], label="Cluster 1", c="r", marker="o")
ax.scatter(dobbel_all[10:20, 0], dobbel_all[10:20, 1], dobbel_all[10:20, 2], label="Cluster 1", c="g", marker="x")
ax.scatter(dobbel_all[20:30, 0], dobbel_all[20:30, 1], dobbel_all[20:30, 2], label="Cluster 1", c="b", marker="o")
ax.scatter(dobbel_all[30:40, 0], dobbel_all[30:40, 1], dobbel_all[30:40, 2], label="Cluster 1", c="c", marker="o")
ax.scatter(dobbel_all[40:50, 0], dobbel_all[40:50, 1], dobbel_all[40:50, 2], label="Cluster 1", c="y", marker="o")
ax.scatter(dobbel_all[50:60, 0], dobbel_all[50:60, 1], dobbel_all[50:60, 2], label="Cluster 1", c="m", marker="o")
ax.scatter(dobbel_all[60:70, 0], dobbel_all[60:70, 1], dobbel_all[60:70, 2], label="Cluster 1", c="k", marker="o")


ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.title("Clustered 3D Data")
ax.legend()

# Display the 3D plot
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Create a 3D scatter plot
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

# Define marker styles and colors for each cluster
markers = ['o', 's', '^']
colors = ['r', 'g', 'b']

# Plot data points based on cluster labels
ax.scatter(dobbel_all[:10, 0], dobbel_all[:10, 1], dobbel_all[:10, 2], label="Cluster 1", c="r", marker="o")
ax.scatter(dobbel_all[10:20, 0], dobbel_all[10:20, 1], dobbel_all[10:20, 2], label="Cluster 1", c="g", marker="x")
ax.scatter(dobbel_all[20:30, 0], dobbel_all[20:30, 1], dobbel_all[20:30, 2], label="Cluster 1", c="b", marker="o")
ax.scatter(dobbel_all[30:40, 0], dobbel_all[30:40, 1], dobbel_all[30:40, 2], label="Cluster 1", c="c", marker="o")
ax.scatter(dobbel_all[40:50, 0], dobbel_all[40:50, 1], dobbel_all[40:50, 2], label="Cluster 1", c="y", marker="o")
ax.scatter(dobbel_all[50:60, 0], dobbel_all[50:60, 1], dobbel_all[50:60, 2], label="Cluster 1", c="m", marker="o")
ax.scatter(dobbel_all[60:70, 0], dobbel_all[60:70, 1], dobbel_all[60:70, 2], label="Cluster 1", c="k", marker="o")

# Add labels and legend
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Z-axis')
plt.title("Clustered 3D Data")
ax.legend()

# Interactive 3D rotation
def on_move(event):
    ax.view_init(elev=event.xdata, azim=event.ydata)
    fig.canvas.draw()

fig.canvas.mpl_connect('motion_notify_event', on_move)

# Display the interactive 3D plot
plt.show()
